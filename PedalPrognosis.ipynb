# %%
# !pip install pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
path = "/london_merged.csv"
df = pd.read_csv(f"{path}")
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df.shape
# Out:
# (17414, 10)

# %%
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# ...

# %%
df.weather_code.value_counts()
# Out:
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: weather_code, dtype: int64

# %%
df.season.value_counts()
# Out:
# 0.0    4394
# 1.0    4387
# 3.0    4330
# 2.0    4303
# Name: season, dtype: int64

# %%
df.columns
# Out:
# Index(['timestamp', 'cnt', 't1', 't2', 'hum', 'wind_speed', 'weather_code',
#        'is_holiday', 'is_weekend', 'season'],
#       dtype='object')

# %%
#below are my new column names
df_new_column =  {
    'timestamp':'time',
    'cnt':'count',
    't1': 'team_real_C',
    't2':'team_feel_like_c',
    'hum':'humidity_percentage',
    'wind_speed':'wind_speed_kph',
    'weather_code':'weather',
    'is_holiday':'is_holiday',
    'is_weekend':'is_weekend',
    'season':'season'

}

#re-naming my old columns
df.rename(df_new_column, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['time', 'count', 'team_real_C', 'team_feel_like_c', 'humidity',
#        'wind_speed_kph', 'weather', 'is_holiday', 'is_weekend', 'season'],
#       dtype='object')

# %%
df.rename({'humidity':'humidity_percentage'},axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['time', 'count', 'team_real_C', 'team_feel_like_c',
#        'humidity_percentage', 'wind_speed_kph', 'weather', 'is_holiday',
#        'is_weekend', 'season'],
#       dtype='object')

# %%
df.weather.value_counts()
# Out:
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: weather, dtype: int64

# %%
season_dict = {
    '0.0':'spring',
    '1.0':'summer',
    '2.0':'autum',
    '3.0':'winter'
}

weather_dict = {
    '1.0':'Clear',
    '2.0':'Scattered clouds',
    '3.0':'Broken clouds',
    '4.0':'Cloudy',
    '7.0':'Rain',
    '10.0':'Rain with thunderstorm',
    '26.0':'Snowfall'
}


df.season = df.season.astype('str')

df.weather = df.weather.astype('str')

df.season = df.season.map(season_dict)

df.weather = df.weather.map(weather_dict)

df.head()
# Out:
#                   time  count  team_real_C  team_feel_like_c  \
# 0  2015-01-04 00:00:00    182          3.0               2.0
# 1  2015-01-04 01:00:00    138          3.0               2.5
# 2  2015-01-04 02:00:00    134          2.5               2.5
# 3  2015-01-04 03:00:00     72          2.0               2.0
# 4  2015-01-04 04:00:00     47          2.0               0.0
#
#    humidity_percentage  wind_speed_kph        weather  is_holiday  is_weekend  \
# 0                 93.0             6.0  Broken clouds         0.0         1.0
# 1                 93.0             5.0          Clear         0.0         1.0
# 2                 96.5             0.0          Clear         0.0         1.0
# 3                100.0             0.0          Clear         0.0         1.0
# 4                 93.0             6.5          Clear         0.0         1.0
#
#    season
# 0  winter
# 1  winter
# 2  winter
# 3  winter
# 4  winter

# %%
df.to_excel('london_bikes_final.xlsx', sheet_name='Data')
